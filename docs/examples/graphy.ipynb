# %%
import shape2graph
import geopandas as gpd
from shape2graph.graph import *

# %%
# vector_path = r"D:\\IOEPulchowkMasterElective\\NetworkAnalysis_GT\\NetworkAnalysis\\3_SRN_TopologyCorrectedHighways.shp"
# clean_gdf = correct_topology(vector_path)

# create_interactive_router(clean_gdf)
